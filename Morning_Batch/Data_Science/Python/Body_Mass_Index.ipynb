# %%
import numpy as np
h = np.array(sorted(np.random.random(1000)*7.2))
w = np.array(sorted(np.random.random(1000)*90.5))

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(w,h)
plt.plot(w,h,'r')
plt.show()

# %%
s,i,r,p,err = stats.linregress(w,h)

# %%
r**2
# Out:
# 0.9987484401087706

# %%
h = np.array(np.random.random(1000)*7.2)
w = np.array(np.random.random(1000)*90.5)
plt.scatter(w,h)
plt.show()

# %%
np.random.seed(1)
height = np.random.normal(6.0,2.0,1000)
weight = np.random.normal(18.0,2.0,1000)*height 
plt.scatter(weight,height)
plt.show()

# %%
slope,intercept,r_value,p_value,std_err = stats.linregress(weight,height)
r_value**2
# Out:
# 0.8834186921518489

# %%
slope
# Out:
# 0.04812035125906558

# %%
intercept
# Out:
# 0.7931567293580697

# %%
w = float(input("Enter your weight : "))
h = slope*w+intercept
print("Your height is : ",1.5*h)
# Out:
# Enter your weight : 68
# Your height is :  6.0980109224617935

# %%
def predict(x):
    return slope * x + intercept

# %%
prediction_value = predict(weight)

# %%
plt.scatter(weight,height)
plt.plot(weight,prediction_value,'r')
plt.show()

# %%
w = np.random.normal(75.0,15.0,10000)
p = predict(w)
plt.scatter(weight,height)
plt.plot(w,p,'r')
plt.show()

# %%
height = np.random.normal(6.0,2.0,1000)
weight = np.random.normal(65.0,20.0,1000)*height/1.5
plt.scatter(weight,height)
plt.show()

# %%
s,i,r,p,error = stats.linregress(height,weight)
def predict(x):
    return s*x+i
pv = predict(height)
plt.scatter(height,weight)
plt.plot(height,pv,'r')
plt.show()

# %%
x = np.array(height)
y = np.array(weight)

p4 = np.poly1d(np.polyfit(y, x, 1))

# %%
plt.scatter(weight,height)
plt.scatter(y,p4(y))
plt.show()

# %%
p4(4)
# Out:
# 7.146186010129085
